# %%
pip install emoji
# Out:
# Requirement already satisfied: emoji in c:\users\hp\anaconda3\lib\site-packages (2.2.0)Note: you may need to restart the kernel to use updated packages.

# %%
pip install joblib
# Out:
# Requirement already satisfied: joblib in c:\users\hp\anaconda3\lib\site-packages (0.16.0)Note: you may need to restart the kernel to use updated packages.

# %%
pip install langdetect
# Out:
# Requirement already satisfied: langdetect in c:\users\hp\anaconda3\lib\site-packages (1.0.9)Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: six in c:\users\hp\anaconda3\lib\site-packages (from langdetect) (1.15.0)

# %%
pip install pytest-warnings
# Out:
# Requirement already satisfied: pytest-warnings in c:\users\hp\anaconda3\lib\site-packages (0.3.1)Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: pytest in c:\users\hp\anaconda3\lib\site-packages (from pytest-warnings) (5.4.3)
# Requirement already satisfied: py>=1.5.0 in c:\users\hp\anaconda3\lib\site-packages (from pytest->pytest-warnings) (1.9.0)
# Requirement already satisfied: packaging in c:\users\hp\anaconda3\lib\site-packages (from pytest->pytest-warnings) (20.4)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\hp\anaconda3\lib\site-packages (from pytest->pytest-warnings) (19.3.0)
# Requirement already satisfied: more-itertools>=4.0.0 in c:\users\hp\anaconda3\lib\site-packages (from pytest->pytest-warnings) (8.4.0)
# Requirement already satisfied: pluggy<1.0,>=0.12 in c:\users\hp\anaconda3\lib\site-packages (from pytest->pytest-warnings) (0.13.1)
# Requirement already satisfied: wcwidth in c:\users\hp\anaconda3\lib\site-packages (from pytest->pytest-warnings) (0.2.5)
# Requirement already satisfied: atomicwrites>=1.0 in c:\users\hp\anaconda3\lib\site-packages (from pytest->pytest-warnings) (1.4.0)
# Requirement already satisfied: colorama in c:\users\hp\anaconda3\lib\site-packages (from pytest->pytest-warnings) (0.4.3)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\hp\anaconda3\lib\site-packages (from packaging->pytest->pytest-warnings) (2.4.7)
# Requirement already satisfied: six in c:\users\hp\anaconda3\lib\site-packages (from packaging->pytest->pytest-warnings) (1.15.0)

# %%
pip install wrap
# Out:
# Requirement already satisfied: wrap in c:\users\hp\anaconda3\lib\site-packages (2018.3.1)Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: logcc in c:\users\hp\anaconda3\lib\site-packages (from wrap) (2018.3.1)
# Requirement already satisfied: pony in c:\users\hp\anaconda3\lib\site-packages (from logcc->wrap) (0.7.16)
# Requirement already satisfied: terminaltables in c:\users\hp\anaconda3\lib\site-packages (from logcc->wrap) (3.1.10)
# Requirement already satisfied: aiohttp in c:\users\hp\anaconda3\lib\site-packages (from logcc->wrap) (3.8.3)
# Requirement already satisfied: websockets in c:\users\hp\anaconda3\lib\site-packages (from logcc->wrap) (10.4)
# Requirement already satisfied: loader in c:\users\hp\anaconda3\lib\site-packages (from logcc->wrap) (2017.9.11)
# Requirement already satisfied: termcc in c:\users\hp\anaconda3\lib\site-packages (from logcc->wrap) (2019.8.2)
# Requirement already satisfied: aiofiles in c:\users\hp\anaconda3\lib\site-packages (from logcc->wrap) (22.1.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\hp\anaconda3\lib\site-packages (from aiohttp->logcc->wrap) (1.3.1)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in c:\users\hp\anaconda3\lib\site-packages (from aiohttp->logcc->wrap) (2.1.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\hp\anaconda3\lib\site-packages (from aiohttp->logcc->wrap) (19.3.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\hp\anaconda3\lib\site-packages (from aiohttp->logcc->wrap) (1.8.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\hp\anaconda3\lib\site-packages (from aiohttp->logcc->wrap) (6.0.2)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in c:\users\hp\anaconda3\lib\site-packages (from aiohttp->logcc->wrap) (4.0.2)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\hp\anaconda3\lib\site-packages (from aiohttp->logcc->wrap) (1.3.3)
# Requirement already satisfied: bs4 in c:\users\hp\anaconda3\lib\site-packages (from loader->logcc->wrap) (0.0.1)
# Requirement already satisfied: pendulum in c:\users\hp\anaconda3\lib\site-packages (from termcc->logcc->wrap) (2.1.2)
# Requirement already satisfied: logbook in c:\users\hp\anaconda3\lib\site-packages (from termcc->logcc->wrap) (1.5.3)
# Requirement already satisfied: idna>=2.0 in c:\users\hp\anaconda3\lib\site-packages (from yarl<2.0,>=1.0->aiohttp->logcc->wrap) (2.10)
# Requirement already satisfied: beautifulsoup4 in c:\users\hp\anaconda3\lib\site-packages (from bs4->loader->logcc->wrap) (4.9.1)
# Requirement already satisfied: python-dateutil<3.0,>=2.6 in c:\users\hp\anaconda3\lib\site-packages (from pendulum->termcc->logcc->wrap) (2.8.1)
# Requirement already satisfied: pytzdata>=2020.1 in c:\users\hp\anaconda3\lib\site-packages (from pendulum->termcc->logcc->wrap) (2020.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\hp\anaconda3\lib\site-packages (from beautifulsoup4->bs4->loader->logcc->wrap) (2.0.1)
# Requirement already satisfied: six>=1.5 in c:\users\hp\anaconda3\lib\site-packages (from python-dateutil<3.0,>=2.6->pendulum->termcc->logcc->wrap) (1.15.0)

# %%
from textwrap import wrap

import emoji
import joblib
import langdetect
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import warnings
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.naive_bayes import MultinomialNB
from sklearn.pipeline import Pipeline
from sklearn.svm import LinearSVC
from sklearn.tree import DecisionTreeClassifier

warnings.filterwarnings("ignore")

# %%
def get_category_dict(category_file):
  category = pd.read_json(category_file, orient="records")
  category = pd.DataFrame(category["items"].values.tolist())

  return{
      cat.id: cat.snippet.get("title")
      for cat in category.itertuples(index=False)
  }

# %%
category_dict = get_category_dict("D:/KULIAH/PELATIHAN DATA/category.json")

# %%
trending = pd.read_csv("D:/KULIAH/PELATIHAN DATA/trending.csv",parse_dates=["publish_time", "trending_time"])

with pd.option_context("display.max_columns", None):
  display(trending.head())
# Out:
#   video_id              publish_time                channel_id  \
# 0      NaN 2021-02-05 09:00:34+00:00  UCEf_Bc-KVd7onSeifS3py9g
# 1      NaN 2021-02-04 15:54:08+00:00  UCYEa4_MC7OFjcWrO6SO-u8g
# 2      NaN 2021-02-06 03:00:22+00:00  UCu12RxQjRQyh79YBYvEDkOg
# 3      NaN 2021-02-05 20:26:08+00:00  UCCuzDCoI3EUOo_nhCj4noSw
# 4      NaN 2021-02-03 23:14:54+00:00  UC14UlmYlSNiQCBe9Eookf_A
#
#                                                title  \
# 0                        aespa 에스파 'Forever (약속)' MV
# 1  [FULL] Siapa di Balik Kudeta AHY? | Dua Sisi t...
# 2     CABRIOLET CHALLENGE: TANTANGAN MENGGODA (7/12)
# 3                        With Windah Basudara & Hans
# 4  🤯 LATE COMEBACK DRAMA! | HIGHLIGHTS | Granada ...
#
#                                          description thumbnail_url  \
# 0  aespa's new single "Forever" is out!\nListen a...           NaN
# 1  Jakarta, https://www.tvonenews.com - Ketua umu...           NaN
# 2  Road Party Season 2: Cabriolet Challenge\n\nEp...           NaN
# 3  Join this channel to get access to perks:\nhtt...           NaN
# 4  With just two minutes to play, Barça looked to...           NaN
#
#    thumbnail_width  thumbnail_height            channel_name  \
# 0              NaN               NaN                  SMTOWN
# 1              NaN               NaN  Indonesia Lawyers Club
# 2              NaN               NaN                Motomobi
# 3              NaN               NaN                      yb
# 4              NaN               NaN            FC Barcelona
#
#                                                 tags  category_id live_status  \
# 0                                                NaN           10        none
# 1  ['tvone', 'tv one', 'tvonenews', 'indonesia la...           25        none
# 2  ['MotoMobi', 'Mobil', 'motor', 'review', 'indo...            2        none
# 3                                                NaN           20        none
# 4  ['FC Barcelona', 'برشلونة،', 'Fútbol', 'FUTBOL...           17        none
#
#                                          local_title  \
# 0                        aespa 에스파 'Forever (약속)' MV
# 1  [FULL] Siapa di Balik Kudeta AHY? | Dua Sisi t...
# 2     CABRIOLET CHALLENGE: TANTANGAN MENGGODA (7/12)
# 3                        With Windah Basudara & Hans
# 4  🤯 LATE COMEBACK DRAMA! | HIGHLIGHTS | Granada ...
#
#                                    local_description  duration dimension  \
# 0  aespa's new single "Forever" is out!\nListen a...    PT5M7S        2d
# 1  Jakarta, https://www.tvonenews.com - Ketua umu...  PT42M30S        2d
# 2  Road Party Season 2: Cabriolet Challenge\n\nEp...  PT46M43S        2d
# 3  Join this channel to get access to perks:\nhtt...  PT45M59S        2d
# 4  With just two minutes to play, Barça looked to...   PT5M12S        2d
#
#   definition  caption  license_status allowed_region blocked_region  \
# 0         hd     True            True            NaN            NaN
# 1         hd    False            True            NaN            NaN
# 2         hd    False            True            NaN            NaN
# 3         hd    False            True            NaN            NaN
# 4         hd    False            True            NaN            NaN
#
#         view      like  dislike  favorite  comment  \
# 0  7806846.0  857902.0  24078.0         0  94961.0
# 1   885038.0    6765.0   1263.0         0   6365.0
# 2   889708.0   47895.0    532.0         0   8785.0
# 3  1006854.0   91973.0   3967.0         0  12957.0
# 4  6275035.0  218131.0   4289.0         0  12799.0
#
#                      trending_time
# 0 2021-02-07 05:46:51.832614+00:00
# 1 2021-02-07 05:46:51.832649+00:00
# 2 2021-02-07 05:46:51.832664+00:00
# 3 2021-02-07 05:46:51.832678+00:00
# 4 2021-02-07 05:46:51.832730+00:00

# %%
start_date = trending.trending_time.min()
end_date = trending.trending_time.max()

print(f"{start_date = }")
print(f"{end_date = }")
# Out:
# start_date = Timestamp('2021-02-07 05:46:51.832614+0000', tz='UTC')
# end_date = Timestamp('2022-11-19 06:02:12.845027+0000', tz='UTC')

# %%
#delete data dari bulan februari-juni

filtered_trending = trending[trending.trending_time.dt.month >= 7]

start_date = filtered_trending.trending_time.min()
end_date = filtered_trending.trending_time.max()

print(f"{start_date = }")
print(f"{end_date = }")
# Out:
# start_date = Timestamp('2021-07-01 06:01:25.524449+0000', tz='UTC')
# end_date = Timestamp('2022-11-19 06:02:12.845027+0000', tz='UTC')

# %%
num_videos = filtered_trending.shape[0]
print(f"{num_videos = }")
# Out:
# num_videos = 63718

# %%
#ditribusi mmissing vallue

filtered_trending.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 63718 entries, 21322 to 118750
# Data columns (total 27 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   video_id           31918 non-null  object
#  1   publish_time       63718 non-null  datetime64[ns, UTC]
#  2   channel_id         63718 non-null  object
#  3   title              63718 non-null  object
#  4   description        61486 non-null  object
#  5   thumbnail_url      31918 non-null  object
#  6   thumbnail_width    31918 non-null  float64
#  7   thumbnail_height   31918 non-null  float64
#  8   channel_name       63718 non-null  object
#  9   tags               55466 non-null  object
#  10  category_id        63718 non-null  int64
#  11  live_status        63718 non-null  object
#  12  local_title        63718 non-null  object
#  13  local_description  61486 non-null  object
#  14  duration           63718 non-null  object
#  15  dimension          63718 non-null  object
#  16  definition         63718 non-null  object
#  17  caption            63718 non-null  bool
#  18  license_status     63718 non-null  bool
#  19  allowed_region     2038 non-null   object
#  20  blocked_region     2399 non-null   object
#  21  view               63718 non-null  float64
#  22  like               63239 non-null  float64
#  23  dislike            32612 non-null  float64
#  24  favorite           63718 non-null  int64
#  25  comment            63547 non-null  float64
#  26  trending_time      63718 non-null  datetime64[ns, UTC]
# dtypes: bool(2), datetime64[ns, UTC](2), float64(6), int64(2), object(15)
# memory usage: 12.8+ MB

# %%
#delete video dengan description kosong

filtered_trending.dropna(subset=["description"], inplace=True)

# %%
trending_by_date = filtered_trending.groupby(
filtered_trending.trending_time.dt.date)

num_trending_per_day = trending_by_date.trending_time.count()
print("Number of videos in trending per day:", num_trending_per_day.unique())
# Out:
# Number of videos in trending per day: [195 196 197 198 194 193 192 191 190 188 187 185 189 186 184 183 132 182
#  181 179 176 172 155 144 149 148 141 140 131 129 145 167 163 157 156 175
#  169 199 200]

# %%
trending_duration = filtered_trending.groupby("title").agg(
trending_duration=pd.NamedAgg(column="trending_time", aggfunc="count"),
trending_start_date=pd.NamedAgg(column="trending_time", aggfunc="min"),
trending_last_date=pd.NamedAgg(column="trending_time", aggfunc="max")
).sort_values("trending_duration", ascending=False).reset_index()
trending_duration.head(10)
# Out:
#                                                title  trending_duration  \
# 0  JEJE PENGHUNI STASIUN DUKUH ATAS, PERNAH CABUT...                 37
# 1        Toleransi antar tetangga di Korea🇰🇷.. 🤦🏻‍♂️                 37
# 2  NEGO 1 GEROBAK SHAWARMA VIRAL DI TIKTOK, SAMPE...                 36
# 3  Tantangin VYN Pake Franco, 1 Kali Kena Hook Da...                 35
# 4                               OPW ARES Sudah Tamat                 35
# 5                          SINGAPORE STREET FOOD #08                 35
# 6  Kok di Indonesia ada penjual Rawon yg lebih pi...                 34
# 7                            SELAMAT LEBARAN GUYS!!!                 33
# 8                            gak bisa bahasa enggres                 32
# 9  HANYA FARIDA NURHAN, MUKBANG MIE GACOAN LEVEL ...                 32
#
#                trending_start_date               trending_last_date
# 0 2022-07-02 06:01:31.621150+00:00 2022-08-07 06:01:00.607537+00:00
# 1 2022-07-02 06:01:31.621606+00:00 2022-08-07 06:01:00.607651+00:00
# 2 2022-07-08 06:01:39.900318+00:00 2022-08-12 06:01:33.892049+00:00
# 3 2022-07-01 06:01:38.284040+00:00 2022-08-04 06:02:04.519603+00:00
# 4 2022-07-02 06:01:31.621296+00:00 2022-08-05 06:02:43.644196+00:00
# 5 2022-07-02 06:01:31.621620+00:00 2022-08-06 06:02:02.694750+00:00
# 6 2022-07-02 06:01:31.621592+00:00 2022-08-04 06:02:04.519738+00:00
# 7 2022-07-11 06:00:59.413948+00:00 2022-08-12 06:01:33.891919+00:00
# 8 2022-07-01 06:01:38.284013+00:00 2022-08-01 06:01:08.899895+00:00
# 9 2022-07-11 06:00:59.414152+00:00 2022-08-11 06:01:46.801212+00:00

# %%
plt.figure(figsize=(15,6))
plt.bar(
    trending_duration.title[:10].apply(lambda title: "\n".join(wrap(title, width=10))),
    trending_duration.trending_duration[:10]
)

plt.title("Longest Duration of Videos included in Youtube Tranding Video", loc="left")
plt.xlabel("Video Title")
plt.ylabel("Trending Duration (in days)")
plt.grid(False)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
trending_by_title = filtered_trending.groupby("title")
trending_rewind = trending_by_title[['view', 'like', 'dislike']].agg(["min", "max","mean", "sum"])
trending_rewind
# Out:
#                                                          view             \
#                                                           min        max
# title
# "Awalnya Diserang Bertubi tubi" Lihatlah Bagaim...   101823.0   121044.0
# "BABY R" BIKIN GEMES !!! RAFATHAR CEMBURU, SEMU...  2280620.0  2637486.0
# "Emosi Rico Simanjutak" Saat Taisei Marukawa Be...    72434.0   116310.0
# "Grebek rumah harris vriza, dan percintaannya d...    68879.0   163773.0
# "Hellevator" Band Cover By Xdinary Heroes (원곡 :...   393043.0  1348612.0
# ...                                                       ...        ...
# 🥘Yuk! Kita coba in! Let’s eat | WayV’s ONE-DAY ...   148668.0   680210.0
# 🥰 New Gadgets & Versatile Utensils For Home # 2...   330156.0  7334655.0
# 🥰 New Gadgets & Versatile Utensils For Home # 3...   278942.0  1212522.0
# 🥰 New Gadgets & Versatile Utensils For Home # 3...   320084.0  1097903.0
# 🩸괴담회에 어서오세요🩸: 첫 번째 이야기 | WELCOME TO NCT’S HORRO...  1423178.0  2966798.0
#
#                                                                               \
#                                                             mean         sum
# title
# "Awalnya Diserang Bertubi tubi" Lihatlah Bagaim...  1.114335e+05    222867.0
# "BABY R" BIKIN GEMES !!! RAFATHAR CEMBURU, SEMU...  2.459053e+06   4918106.0
# "Emosi Rico Simanjutak" Saat Taisei Marukawa Be...  9.390625e+04    375625.0
# "Grebek rumah harris vriza, dan percintaannya d...  1.267565e+05    760539.0
# "Hellevator" Band Cover By Xdinary Heroes (원곡 :...  1.126182e+06  14640369.0
# ...                                                          ...         ...
# 🥘Yuk! Kita coba in! Let’s eat | WayV’s ONE-DAY ...  5.519997e+05   8831995.0
# 🥰 New Gadgets & Versatile Utensils For Home # 2...  3.414214e+06  34142143.0
# 🥰 New Gadgets & Versatile Utensils For Home # 3...  7.948737e+05   5564116.0
# 🥰 New Gadgets & Versatile Utensils For Home # 3...  7.562497e+05   4537498.0
# 🩸괴담회에 어서오세요🩸: 첫 번째 이야기 | WELCOME TO NCT’S HORRO...  2.629831e+06  36817634.0
#
#                                                         like            \
#                                                          min       max
# title
# "Awalnya Diserang Bertubi tubi" Lihatlah Bagaim...    1336.0    1456.0
# "BABY R" BIKIN GEMES !!! RAFATHAR CEMBURU, SEMU...   93348.0  101207.0
# "Emosi Rico Simanjutak" Saat Taisei Marukawa Be...     990.0    1432.0
# "Grebek rumah harris vriza, dan percintaannya d...    5529.0    8714.0
# "Hellevator" Band Cover By Xdinary Heroes (원곡 :...  127824.0  262846.0
# ...                                                      ...       ...
# 🥘Yuk! Kita coba in! Let’s eat | WayV’s ONE-DAY ...   39847.0  101922.0
# 🥰 New Gadgets & Versatile Utensils For Home # 2...    2822.0   58066.0
# 🥰 New Gadgets & Versatile Utensils For Home # 3...    2790.0   10212.0
# 🥰 New Gadgets & Versatile Utensils For Home # 3...    3025.0    8759.0
# 🩸괴담회에 어서오세요🩸: 첫 번째 이야기 | WELCOME TO NCT’S HORRO...  316849.0  457809.0
#
#                                                                               \
#                                                              mean        sum
# title
# "Awalnya Diserang Bertubi tubi" Lihatlah Bagaim...    1396.000000     2792.0
# "BABY R" BIKIN GEMES !!! RAFATHAR CEMBURU, SEMU...   97277.500000   194555.0
# "Emosi Rico Simanjutak" Saat Taisei Marukawa Be...    1228.500000     4914.0
# "Grebek rumah harris vriza, dan percintaannya d...    7486.833333    44921.0
# "Hellevator" Band Cover By Xdinary Heroes (원곡 :...  237112.769231  3082466.0
# ...                                                           ...        ...
# 🥘Yuk! Kita coba in! Let’s eat | WayV’s ONE-DAY ...   87227.125000  1395634.0
# 🥰 New Gadgets & Versatile Utensils For Home # 2...   28320.700000   283207.0
# 🥰 New Gadgets & Versatile Utensils For Home # 3...    6897.571429    48283.0
# 🥰 New Gadgets & Versatile Utensils For Home # 3...    6112.333333    36674.0
# 🩸괴담회에 어서오세요🩸: 첫 번째 이야기 | WELCOME TO NCT’S HORRO...  429081.142857  6007136.0
#
#                                                    dislike          \
#                                                        min     max
# title
# "Awalnya Diserang Bertubi tubi" Lihatlah Bagaim...    40.0    46.0
# "BABY R" BIKIN GEMES !!! RAFATHAR CEMBURU, SEMU...  1197.0  1286.0
# "Emosi Rico Simanjutak" Saat Taisei Marukawa Be...    40.0    61.0
# "Grebek rumah harris vriza, dan percintaannya d...    46.0    74.0
# "Hellevator" Band Cover By Xdinary Heroes (원곡 :...     NaN     NaN
# ...                                                    ...     ...
# 🥘Yuk! Kita coba in! Let’s eat | WayV’s ONE-DAY ...     NaN     NaN
# 🥰 New Gadgets & Versatile Utensils For Home # 2...   283.0  7540.0
# 🥰 New Gadgets & Versatile Utensils For Home # 3...   335.0  1335.0
# 🥰 New Gadgets & Versatile Utensils For Home # 3...   434.0  1115.0
# 🩸괴담회에 어서오세요🩸: 첫 번째 이야기 | WELCOME TO NCT’S HORRO...   479.0  1420.0
#
#
#                                                            mean      sum
# title
# "Awalnya Diserang Bertubi tubi" Lihatlah Bagaim...    43.000000     86.0
# "BABY R" BIKIN GEMES !!! RAFATHAR CEMBURU, SEMU...  1241.500000   2483.0
# "Emosi Rico Simanjutak" Saat Taisei Marukawa Be...    47.750000    191.0
# "Grebek rumah harris vriza, dan percintaannya d...    63.500000    381.0
# "Hellevator" Band Cover By Xdinary Heroes (원곡 :...          NaN      0.0
# ...                                                         ...      ...
# 🥘Yuk! Kita coba in! Let’s eat | WayV’s ONE-DAY ...          NaN      0.0
# 🥰 New Gadgets & Versatile Utensils For Home # 2...  3517.500000  35175.0
# 🥰 New Gadgets & Versatile Utensils For Home # 3...   878.000000   6146.0
# 🥰 New Gadgets & Versatile Utensils For Home # 3...   806.500000   4839.0
# 🩸괴담회에 어서오세요🩸: 첫 번째 이야기 | WELCOME TO NCT’S HORRO...  1238.357143  17337.0
#
# [10046 rows x 12 columns]

# %%
#visualisai trending video teratas masing"

top_10_liked = trending_rewind["like"].sort_values("max", ascending=False).iloc[:10]

plt.figure(figsize=(15, 6))
plt.bar(
top_10_liked.index.to_series().apply(lambda title: "\n".join(wrap(title, width=10))),
top_10_liked["max"],
label="last like"
)
plt.bar(
top_10_liked.index.to_series().apply(lambda title: "\n".join(wrap(title, width=10))),
top_10_liked["min"],
label="start like"
)
plt.title("Most videos in trending list improves drastically in terms of likes", loc="left", y=1.1)
plt.xlabel("Number of like")
plt.ylabel ("Video Title")
plt.legend()
plt.grid(False)
plt.show()

# %%
top_10_liked = trending_rewind["view"].sort_values("max", ascending=False).iloc[:10]

plt.figure(figsize=(15,6))
plt.bar(
    top_10_liked.index.to_series().apply(lambda title: "\n".join(wrap(title, width=10))),
    top_10_liked["max"],
    label="last views")
plt.bar(
    top_10_liked.index.to_series().apply(lambda title: "\n".join(wrap(title, width=10))),
    top_10_liked["min"],
    label="start views")

plt.title("Most videos in trending list improves drastically in terms of likes", loc="left", y=1.1)
plt.xlabel("Number of like")
plt.ylabel ("Video Title")
plt.legend()
plt.grid(False)
plt.show()

# %%
# Language Detection

# %%
sample = filtered_trending.sample(10, random_state=11)
sample[["title", "description"]]
# Out:
#                                                     title  \
# 50234    MAN CITY 3-0 EVERTON | PREMIER LEAGUE HIGHLIGHTS
# 22694   Idgitaf - Berlagak Bahagia (Official Lyric Video)
# 93064           Seharian ngerasain kerjaan jadi SALES HP!
# 47387   UPDATE TERBARU VERSI 1.038.85!! MOTOR BARU LAN...
# 37865   Persaingan Pedagang Bakso – tebar tanah kubura...
# 103946  Melly Goeslaw, Lesti, Nagita Slavina, Celine E...
# 53471   KISAH HARU RUMINI, Meninggal Berpelukan Bersam...
# 103941  EPIC Leon Edwards' coaches inspire him to incr...
# 42589   TANTANGAN MENGHIAS KEIK || Putar Roda Misterin...
# 107739  Teaser | Percy Jackson and the Olympians | Dis...
#
#                                               description
# 50234   Everton fell to defeat at Manchester City in a...
# 22694   Berlagak Bahagia (Official Lyric Video)\nStrea...
# 93064   Boleh hape murah kaka...\n\nBarang bekas revie...
# 47387   Hello guys..kita lanjut lagi main Sakura Schoo...
# 37865   Join this channel to get access to perks:\nhtt...
# 103946  RUMAH KITA - MELLY GOESLAW, NAGITA SLAVINA, LE...
# 53471   SURYA.co.id, LUMAJANG - Korban meninggal letus...
# 103941  Leon Edwards did the unthinkable by defeating ...
# 42589   Kalau kita membayangkan keik, kita pasti ngeba...
# 107739  For more updates, subscribe to Disney, Pixar, ...

# %%
sample["title_lang"] = sample.title.apply(lambda title: langdetect.detect(title.lower()))
sample["desc_lang"] = sample.description.apply(lambda desc: langdetect.detect(desc.lower()))

# %%
with pd.option_context("display.max_colwidth", 100):
    display(sample[["title", "title_lang", "description", "desc_lang"]])
# Out:
#                                                                                                       title  \
# 50234                                                      MAN CITY 3-0 EVERTON | PREMIER LEAGUE HIGHLIGHTS
# 22694                                                     Idgitaf - Berlagak Bahagia (Official Lyric Video)
# 93064                                                             Seharian ngerasain kerjaan jadi SALES HP!
# 47387   UPDATE TERBARU VERSI 1.038.85!! MOTOR BARU LANGSUNG BUAT BALAPAN!! SAKURA SCHOOL SIMULATOR-PART 494
# 37865    Persaingan Pedagang Bakso – tebar tanah kuburan agar bangkrut  #HORORMISTERI | Kartun hantu pocong
# 103946         Melly Goeslaw, Lesti, Nagita Slavina, Celine Evangelista - Rumah Kita | Official Music Video
# 53471                  KISAH HARU RUMINI, Meninggal Berpelukan Bersama Ibunya Digulung Wedhus Gembel Semeru
# 103941     EPIC Leon Edwards' coaches inspire him to incredible comeback win! | Usman v Edwards 2 | UFC 278
# 42589            TANTANGAN MENGHIAS KEIK || Putar Roda Misterinya! 100 Lapis MAKANAN oleh 123 GO! CHALLENGE
# 107739                                                   Teaser | Percy Jackson and the Olympians | Disney+
#
#        title_lang  \
# 50234          en
# 22694          en
# 93064          id
# 47387          id
# 37865          id
# 103946         it
# 53471          id
# 103941         en
# 42589          id
# 107739         en
#
#                                                                                                 description  \
# 50234   Everton fell to defeat at Manchester City in a difficult afternoon at Etihad Stadium. Raheem Ste...
# 22694   Berlagak Bahagia (Official Lyric Video)\nStream "Berlagak Bahagia" in your favorite platform: ht...
# 93064   Boleh hape murah kaka...\n\nBarang bekas review biasanya saya jual disini: https://invol.co/cl75...
# 47387   Hello guys..kita lanjut lagi main Sakura School  Part 494 yaa. Kali ini Sakurani Review UPDATE T...
# 37865   Join this channel to get access to perks:\nhttps://www.youtube.com/channel/UC7GWXKxiy9_AU9TytEh0...
# 103946  RUMAH KITA - MELLY GOESLAW, NAGITA SLAVINA, LESTI, CELINE EVANGELISTA\n#RumahKita #PulihLebihCep...
# 53471   SURYA.co.id, LUMAJANG - Korban meninggal letusan Semeru mulai ditemukan. Dua di antaranya adalah...
# 103941  Leon Edwards did the unthinkable by defeating Kamaru Usman and becoming the UFC welterweight Cha...
# 42589   Kalau kita membayangkan keik, kita pasti ngebayangin berlapis-lapis dengan cokelat manis, tabura...
# 107739  For more updates, subscribe to Disney, Pixar, Marvel, Star Wars, and National Geographic.\n \nDi...
#
#        desc_lang
# 50234         en
# 22694         en
# 93064         id
# 47387         id
# 37865         id
# 103946        id
# 53471         id
# 103941        en
# 42589         id
# 107739        en

# %%
# pertama mendeteksi bahasa dari sebuah teks

def detect_language(text):
    """Detect language of the 'text'."""
    try: 
        lang = langdetect.detect(text)
        return lang
    except:
        return

# %%
filtered_trending["title_lang"] = filtered_trending["title"].apply(detect_language)
filtered_trending["desc_lang"] = filtered_trending["description"].apply(detect_language)

# %%
filtered_trending[["title", "title_lang", "description", "desc_lang"]]
# Out:
#                                                     title title_lang  \
# 21322                  NCT DREAM 엔시티 드림 'Hello Future' MV         it
# 21323               PART 3 // SUTRISNO DAN ENDANG BAHAGIA         de
# 21324   This isn't David Copperfield Magic trick😂 #sho...         en
# 21325    Rizky Billar - Pemimpinmu | Official Music Video         en
# 21326   Ini Pengakuan Pengemudi Pajero usai Rusak dan ...         id
# ...                                                   ...        ...
# 118746  NASI GORENG BAKAR INI PINDAH SAMPAI 13 KALI KA...         de
# 118747  KENAL DEKAT DENGAN KELUARGA NATHALIE, PAPA SAY...         de
# 118748                            YOUNITE 'Bad Cupid' M/V         en
# 118749  Cover | JAEHYUN - Can't Take My Eyes Off You (...         en
# 118750  PAPA SAYANG PDKT LEWAT FACEBOOK | NATHALIE DIA...         en
#
#                                               description desc_lang
# 21322   NCT DREAM's 1st Album Repackage "Hello Future"...        en
# 21323   Find me on sosial media :\n\nInstagram : https...        en
# 21324   Thank you for watching.\nSubscribe to Tsuriki ...        en
# 21325   Rizky Billar - Pemimpinmu | Official Music Vid...        id
# 21326   Polisi menangkap pengemudi SUV yang merusak da...        id
# ...                                                   ...       ...
# 118746  HAHHH JUALAN NASI GORENG INI UDAH 13 KALI PIND...        id
# 118747  Hi, welcome to Nathalie Holscher Channel!\n\nF...        id
# 118748  YOUNITE 'Bad Cupid' M/V\n\n'YOUNI-ON' Availabl...        en
# 118749  #Cover #JAEHYUN\n#CantTakeMyEyesOffYou #Franki...        en
# 118750  Hi, welcome to Nathalie Holscher Channel!\n\nF...        id
#
# [61486 rows x 4 columns]

# %%
indo_trending = filtered_trending.loc[
    (filtered_trending.title_lang == "id") | (filtered_trending.desc_lang == "id")
]

with pd.option_context("display.max_columns", None):
    display(indo_trending.sample(10))
# Out:
#            video_id              publish_time                channel_id  \
# 109563  oMeI7oWvZbc 2022-10-04 10:15:01+00:00  UCuVxJ829ysWH2OhZJiWdnbg
# 96381   IuieSmopjVg 2022-07-27 12:47:35+00:00  UCyW9SCiTYKCF-KCGi83RD3w
# 102927  gF93C9qxPHk 2022-08-15 08:15:12+00:00  UCxv2IqPMhL3kl8cKZWsiMlg
# 48804           NaN 2021-11-07 12:00:03+00:00  UCwXPLUOgfDRdDuDQup-mWNQ
# 98127   wdGJkWKdkas 2022-07-25 07:22:11+00:00  UCpLNlD983zCbsHYQqPPQs4Q
# 114353  aaVCD4-K2do 2022-10-27 12:26:40+00:00  UCFuM3BWlLM3YbLjkXBiJ8-A
# 47021           NaN 2021-10-29 16:45:26+00:00  UCeM5Nksgv9_FXTuZ8jkPJPg
# 99829   jeeU9Jbg_Gw 2022-08-10 12:00:12+00:00  UCkd0ak3k34CPwkQlO2JnijA
# 94602   hC_-KAFLO18 2022-06-28 13:00:32+00:00  UCuVxJ829ysWH2OhZJiWdnbg
# 39188           NaN 2021-09-19 02:00:24+00:00  UCvh1at6xpV1ytYOAzxmqUsA
#
#                                                     title  \
# 109563     Saya Balik Main Kagura Lagi?! - Mobile Legends
# 96381   Nopek bingung liat harga cafe di PIK? Date sep...
# 102927  Justy Aldrin - Rumah Par Ale (Official Music V...
# 48804   VIRAL! MIE PEDAS MEMATIKAN! SAMYANG LOKAL! HAR...
# 98127   CARA BARU MAIN BEATRIX? DIBIKIN BEGINI JADI SA...
# 114353         TUTORIAL MASAK ANTI GAGAL FT. JEROME POLIN
# 47021   MAS AL SAMPE NGAKAK NGELIHAT REYNA KEBINGUNGAN...
# 99829   SURPRISE DEDE LESTI PAKE MARTABAK?!! | Lilis D...
# 94602   LEOMORD SEKARANG SIH ENAK BANGET GUYS !! - Mob...
# 39188             Makanan Rp10,000 vs Makanan Rp1,000,000
#
#                                               description  \
# 109563  Yuk gabung jadi member channel youtube aku mel...
# 96381   Thank you for watching! Jangan lupa like & com...
# 102927  Di atas Tanah Marapu, Tanah Sumba, Prov. NTT ....
# 48804   MIE JEUBEW TEH EMIL\nJl. Pahlawan No.24, Sukag...
# 98127   TOPUP DIAMOND TERMURAH DIBANDING TOKO LAIN, AD...
# 114353  Social Media:\nhttps://www.youtube.com/jessica...
# 47021   MAS AL SAMPE NGAKAK NGELIHAT REYNA KEBINGUNGAN...
# 99829   Pasukan kepo, jangan lupa subscribe, share, li...
# 94602   Yuk gabung jadi member channel youtube aku mel...
# 39188   Kali ini aku bareng sama @Jessica Jane akan ch...
#
#                                            thumbnail_url  thumbnail_width  \
# 109563  https://i.ytimg.com/vi/oMeI7oWvZbc/hqdefault.jpg            480.0
# 96381   https://i.ytimg.com/vi/IuieSmopjVg/hqdefault.jpg            480.0
# 102927  https://i.ytimg.com/vi/gF93C9qxPHk/hqdefault.jpg            480.0
# 48804                                                NaN              NaN
# 98127   https://i.ytimg.com/vi/wdGJkWKdkas/hqdefault.jpg            480.0
# 114353  https://i.ytimg.com/vi/aaVCD4-K2do/hqdefault.jpg            480.0
# 47021                                                NaN              NaN
# 99829   https://i.ytimg.com/vi/jeeU9Jbg_Gw/hqdefault.jpg            480.0
# 94602   https://i.ytimg.com/vi/hC_-KAFLO18/hqdefault.jpg            480.0
# 39188                                                NaN              NaN
#
#         thumbnail_height              channel_name  \
# 109563             360.0                 RRQ Lemon
# 96381              360.0               Livy Renata
# 102927             360.0     JUSTY ALDRIN OFFICIAL
# 48804                NaN            Gerry Girianza
# 98127              360.0                   leokoce
# 114353             360.0              Jessica Jane
# 47021                NaN      RCTI - ENTERTAINMENT
# 99829              360.0  Lilis Darawangi Official
# 94602              360.0                 RRQ Lemon
# 39188                NaN             Jess No Limit
#
#                                                      tags  category_id  \
# 109563  ['lemon', 'rrq lemon', 'lemon rrq', 'team rrq'...           20
# 96381   ['Livy Renata', 'alter ego', 'brand ambassador...           20
# 102927  ['justy aldrin', 'justy aldrin official', 'Rum...           10
# 48804   ['Bakso', 'Pentol ceker begal', 'Bakso viral',...           22
# 98127                                                 NaN           20
# 114353  ['JESSICA JANE', 'JESIKA JANE', '24 JAM JESSIC...           24
# 47021   ['RCTI', 'Dahsyatnya 2020', 'Raffi Ahmad', 'De...           24
# 99829   ['lilis darawangi', 'lilis darawangi official'...           24
# 94602   ['lemon', 'rrq lemon', 'lemon rrq', 'team rrq'...           20
# 39188   ['jess no limit', 'jes', 'jess', 'no limit', '...           24
#
#        live_status                                        local_title  \
# 109563        none     Saya Balik Main Kagura Lagi?! - Mobile Legends
# 96381         none  Nopek bingung liat harga cafe di PIK? Date sep...
# 102927        none  Justy Aldrin - Rumah Par Ale (Official Music V...
# 48804         none  VIRAL! MIE PEDAS MEMATIKAN! SAMYANG LOKAL! HAR...
# 98127         none  CARA BARU MAIN BEATRIX? DIBIKIN BEGINI JADI SA...
# 114353        none         TUTORIAL MASAK ANTI GAGAL FT. JEROME POLIN
# 47021         none  MAS AL SAMPE NGAKAK NGELIHAT REYNA KEBINGUNGAN...
# 99829         none  SURPRISE DEDE LESTI PAKE MARTABAK?!! | Lilis D...
# 94602         none  LEOMORD SEKARANG SIH ENAK BANGET GUYS !! - Mob...
# 39188         none            Makanan Rp10,000 vs Makanan Rp1,000,000
#
#                                         local_description  duration dimension  \
# 109563  Yuk gabung jadi member channel youtube aku mel...   PT9M50S        2d
# 96381   Thank you for watching! Jangan lupa like & com...  PT20M19S        2d
# 102927  Di atas Tanah Marapu, Tanah Sumba, Prov. NTT ....   PT5M17S        2d
# 48804   MIE JEUBEW TEH EMIL\nJl. Pahlawan No.24, Sukag...  PT26M21S        2d
# 98127   TOPUP DIAMOND TERMURAH DIBANDING TOKO LAIN, AD...  PT15M54S        2d
# 114353  Social Media:\nhttps://www.youtube.com/jessica...  PT22M55S        2d
# 47021   MAS AL SAMPE NGAKAK NGELIHAT REYNA KEBINGUNGAN...  PT14M13S        2d
# 99829   Pasukan kepo, jangan lupa subscribe, share, li...   PT2M48S        2d
# 94602   Yuk gabung jadi member channel youtube aku mel...  PT11M51S        2d
# 39188   Kali ini aku bareng sama @Jessica Jane akan ch...  PT17M15S        2d
#
#        definition  caption  license_status allowed_region blocked_region  \
# 109563         hd    False            True            NaN            NaN
# 96381          hd    False            True            NaN            NaN
# 102927         hd     True            True            NaN            NaN
# 48804          hd    False            True            NaN            NaN
# 98127          hd    False            True            NaN            NaN
# 114353         hd    False            True            NaN            NaN
# 47021          hd    False            True            NaN            NaN
# 99829          hd    False            True            NaN            NaN
# 94602          hd    False            True            NaN            NaN
# 39188          hd    False            True            NaN            NaN
#
#              view     like  dislike  favorite  comment  \
# 109563   199722.0   9956.0      NaN         0    814.0
# 96381    632359.0  18029.0      NaN         0   1747.0
# 102927   863145.0  43446.0      NaN         0   1765.0
# 48804   1143816.0  36925.0    631.0         0   1297.0
# 98127    368479.0  11530.0      NaN         0    518.0
# 114353  1115992.0  73588.0      NaN         0   3984.0
# 47021   1263383.0  16803.0    659.0         0    567.0
# 99829     35543.0   2107.0      NaN         0    121.0
# 94602    877731.0  26188.0      NaN         0   1148.0
# 39188   1922033.0  94940.0   1643.0         0   2444.0
#
#                           trending_time title_lang desc_lang
# 109563 2022-10-05 06:01:46.728051+00:00         id        id
# 96381  2022-07-30 06:02:45.467652+00:00         id        en
# 102927 2022-09-01 06:01:39.460028+00:00         en        id
# 48804  2021-11-15 06:02:48.688380+00:00         de        id
# 98127  2022-08-08 06:01:51.313576+00:00         de        id
# 114353 2022-10-29 06:01:12.885317+00:00         en        id
# 47021  2021-11-06 06:05:00.137997+00:00         en        id
# 99829  2022-08-17 06:01:52.078101+00:00         en        id
# 94602  2022-07-18 06:01:54.137797+00:00         de        id
# 39188  2021-09-28 06:01:04.887131+00:00         id        id

# %%
data = indo_trending[["title", "description", "category_id"]].reset_index(drop=True)
data
# Out:
#                                                    title  \
# 0       Rizky Billar - Pemimpinmu | Official Music Video
# 1      Ini Pengakuan Pengemudi Pajero usai Rusak dan ...
# 2      Aksi Demo Tolak Kedatangan Jokowi di Kendari B...
# 3      PERTAMA KALI LIAT SAPI SEGEDE GINI, DINAIKIN D...
# 4      PODKESMAS SAMPAI GA NYAMAN DIBAHAS DISINI - To...
# ...                                                  ...
# 38039  Ariel NOAH x Enda Ungu - Yang Terdalam (Live a...
# 38040  Farel Prayoga Feat Dini Kurnia _CINTA TAK TERP...
# 38041  NASI GORENG BAKAR INI PINDAH SAMPAI 13 KALI KA...
# 38042  KENAL DEKAT DENGAN KELUARGA NATHALIE, PAPA SAY...
# 38043  PAPA SAYANG PDKT LEWAT FACEBOOK | NATHALIE DIA...
#
#                                              description  category_id
# 0      Rizky Billar - Pemimpinmu | Official Music Vid...           10
# 1      Polisi menangkap pengemudi SUV yang merusak da...           25
# 2      Tanggal Tayang: 30/06/2021\n\nProgram berita h...           25
# 3      Assalamualaikum gaeess..! sudah nonton video s...           15
# 4      Talk show malam yang akan memberikan informasi...           24
# ...                                                  ...          ...
# 38039  Ariel NOAH x Enda Ungu - Yang Terdalam\n\nOrig...           10
# 38040  Farel Prayoga Feat Dini Kurnia _CINTA TAK TERP...           10
# 38041  HAHHH JUALAN NASI GORENG INI UDAH 13 KALI PIND...           22
# 38042  Hi, welcome to Nathalie Holscher Channel!\n\nF...           24
# 38043  Hi, welcome to Nathalie Holscher Channel!\n\nF...           24
#
# [38044 rows x 3 columns]

# %%
data.drop_duplicates(subset="title", inplace=True)

# %%
data.reset_index(drop=True, inplace=True)
data.shape
# Out:
# (6157, 3)

# %% [markdown]
# # Feature engineering

# %%
pip install emoji
# Out:
# Requirement already satisfied: emoji in c:\users\hp\anaconda3\lib\site-packages (1.7.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install emoji==1.7
# Out:
# Requirement already satisfied: emoji==1.7 in c:\users\hp\anaconda3\lib\site-packages (1.7.0)Note: you may need to restart the kernel to use updated packages.

# %%
import emoji
list_emoji = [e for e in emoji.UNICODE_EMOJI.get("en")]
count = 0 
for em in list_emoji:
    for title in data.title:
        if em in title:
            count += 1
print("How many titles use emoji?", count)
# Out:
# How many titles use emoji? 785

# %%
def demojize(text):
    for em in list_emoji:
        if em in text:
            em_text = emoji.demojize(em)
            text = text.replace(em, " " + em_text + " ")
            return text

# %%
data["title_emoji"] = data.title.apply(demojize)

# %%
title_with_emoji_idx = [
    idx for idx in range(len(data.title))
    for em in list_emoji
    if em in data.loc[idx, "title"]
]

# %%
with pd.option_context("display.max_colwidth", 100):
    display(data.loc[title_with_emoji_idx])
# Out:
#                                                                                                    title  \
# 33    Dari Jendela Smp : GREGETTT...Wih kelihatannya Wulan jadi primadona di SMA Merdeka Mandiri nih...❤
# 78       BIKIN CEWEK TERPESONA 😍 Aksi Heroik Driver Muda Menolong Sopir Yang Kesulitan di Sitinjau Lauik
# 80                                         15 MENIT MEMBAKAR LEMAK 1 Kg !!! 24 Jam TIMBANGAN TURUN ✅ ✅ ✅
# 148                                            WHY‼️ SAYA DISOMASI, TOLOOONG...- Deddy Corbuzier Podcast
# 148                                            WHY‼️ SAYA DISOMASI, TOLOOONG...- Deddy Corbuzier Podcast
# ...                                                                                                  ...
# 6115                                 Dasar orang Korea...Makan nasi goreng aja bahagia bingit bingit!!🥰🥰
# 6116                                                KITA BEREMPAT MAIN PETAK UMPET DI MAP BUATAN ISTRI 😁
# 6124                                            Semoga HP ini LAKU KERAS 🙏🏻 - Review Zenfone 9 Indonesia
# 6124                                            Semoga HP ini LAKU KERAS 🙏🏻 - Review Zenfone 9 Indonesia
# 6124                                            Semoga HP ini LAKU KERAS 🙏🏻 - Review Zenfone 9 Indonesia
#
#                                                                                               description  \
# 33    Saksikan #DariJendelaSMP Setiap Hari Pkl. 16.40 WIB hanya di @Surya Citra Televisi (SCTV) \n@sin...
# 78    Aksi heroik driver muda membantu sopir minibus yang kesulitan di Sitinjau Lauik\n\ninstagram : h...
# 80    15 menit membakar lemak, ok ! siapa yg workout mengharapkan bisa membakar 1 kg lemak dalam 15 me...
# 148   #somasi #odgj #podcast\nTEMAN TEMAN KONTEN CREATOR, JANGAN TAKUT BERKARYA SELAMA TUJUAN KALIAN B...
# 148   #somasi #odgj #podcast\nTEMAN TEMAN KONTEN CREATOR, JANGAN TAKUT BERKARYA SELAMA TUJUAN KALIAN B...
# ...                                                                                                   ...
# 6115  #인도네시아음식#나시고랭#미고랭\nMukbang nasi goreng mie goreng makanan paling dasar Indonesia!!\n\nNasi Goren...
# 6116  - Subcribe Gratis : https://goo.gl/9DnNkc\n- Join TeguhTeam  : https://www.youtube.com/channel/U...
# 6124  Udah lama ga muji HP sampe segininya.\n\nDapatkan pengalaman baru menikmati Kopi Kapal Api Speci...
# 6124  Udah lama ga muji HP sampe segininya.\n\nDapatkan pengalaman baru menikmati Kopi Kapal Api Speci...
# 6124  Udah lama ga muji HP sampe segininya.\n\nDapatkan pengalaman baru menikmati Kopi Kapal Api Speci...
#
#       category_id  \
# 33             24
# 78              2
# 80             26
# 148            24
# 148            24
# ...           ...
# 6115           24
# 6116           20
# 6124           28
# 6124           28
# 6124           28
#
#                                                                                               title_emoji
# 33    Dari Jendela Smp : GREGETTT...Wih kelihatannya Wulan jadi primadona di SMA Merdeka Mandiri nih.....
# 78    BIKIN CEWEK TERPESONA  :smiling_face_with_heart-eyes:  Aksi Heroik Driver Muda Menolong Sopir Ya...
# 80    15 MENIT MEMBAKAR LEMAK 1 Kg !!! 24 Jam TIMBANGAN TURUN  :check_mark_button:   :check_mark_butto...
# 148                    WHY :double_exclamation_mark:  SAYA DISOMASI, TOLOOONG...- Deddy Corbuzier Podcast
# 148                    WHY :double_exclamation_mark:  SAYA DISOMASI, TOLOOONG...- Deddy Corbuzier Podcast
# ...                                                                                                   ...
# 6115  Dasar orang Korea...Makan nasi goreng aja bahagia bingit bingit!! :smiling_face_with_hearts:  :s...
# 6116                KITA BEREMPAT MAIN PETAK UMPET DI MAP BUATAN ISTRI  :beaming_face_with_smiling_eyes:
# 6124                              Semoga HP ini LAKU KERAS  :folded_hands: 🏻 - Review Zenfone 9 Indonesia
# 6124                              Semoga HP ini LAKU KERAS  :folded_hands: 🏻 - Review Zenfone 9 Indonesia
# 6124                              Semoga HP ini LAKU KERAS  :folded_hands: 🏻 - Review Zenfone 9 Indonesia
#
# [785 rows x 4 columns]

# %%
#delete kolom title

data.drop(columns="title", inplace=True)

# %% [markdown]
# # Eksplorasi

# %%
desc_with_emoji_idx = [
    idx for idx in range(len(data.description))
    for em in list_emoji
    if em in data.loc[idx, "description"]
]

data["desc_emoji"] = data.description.apply(demojize)

with pd.option_context("display.max_colwidth", 100):
    display(data.loc[desc_with_emoji_idx])
# Out:
#                                                                                               description  \
# 0     Rizky Billar - Pemimpinmu | Official Music Video\n\nSurprise Untuk Dede Lesti :\nhttps://youtu.b...
# 10    Title: Sempurnakan Hariku \nArtist: Rey Mbayang\nComposser: Rey Mbayang, Trakast\nMusic Arranger...
# 11    Title: Apa Kabar Mantan\nArtist: Yeni Inka\nSongwriter: Yonanda NDX\n\nFollow juga kita disini y...
# 11    Title: Apa Kabar Mantan\nArtist: Yeni Inka\nSongwriter: Yonanda NDX\n\nFollow juga kita disini y...
# 13    #ByoodeJanganCobaCoba #Byoode #MusicVideo #Girlband #Dangdut\n\nDengerin lagu Byoode - Jangan Co...
# ...                                                                                                   ...
# 6135  Match antara Manchester City vs Brentford pada Liga Inggris musim 2022/2023 dimenangkan oleh Bre...
# 6137  “Khayalan Tingkat Tinggi” bercerita tentang seseorang yang jatuh cinta pada pandangan pertama, t...
# 6139  #sule #njan #ratu #inibukantalkshow \nJangan lupa subscribe, like, share & comment S-PRO!\n\nLan...
# 6142  Official Music Video MANGKU PUREL"SHEPIN MISA"\nSongwriter by  NURBAYAN\nArangger by: DR.STUDIO\...
# 6142  Official Music Video MANGKU PUREL"SHEPIN MISA"\nSongwriter by  NURBAYAN\nArangger by: DR.STUDIO\...
#
#       category_id title_emoji  \
# 0              10        None
# 10             10        None
# 11             10        None
# 11             10        None
# 13             10        None
# ...           ...         ...
# 6135           17        None
# 6137           10        None
# 6139           24        None
# 6142           10        None
# 6142           10        None
#
#                                                                                                desc_emoji
# 0     Rizky Billar - Pemimpinmu | Official Music Video\n\nSurprise Untuk Dede Lesti :\nhttps://youtu.b...
# 10    Title: Sempurnakan Hariku \nArtist: Rey Mbayang\nComposser: Rey Mbayang, Trakast\nMusic Arranger...
# 11    Title: Apa Kabar Mantan\nArtist: Yeni Inka\nSongwriter: Yonanda NDX\n\nFollow juga kita disini y...
# 11    Title: Apa Kabar Mantan\nArtist: Yeni Inka\nSongwriter: Yonanda NDX\n\nFollow juga kita disini y...
# 13    #ByoodeJanganCobaCoba #Byoode #MusicVideo #Girlband #Dangdut\n\nDengerin lagu Byoode - Jangan Co...
# ...                                                                                                   ...
# 6135  Match antara Manchester City vs Brentford pada Liga Inggris musim 2022/2023 dimenangkan oleh Bre...
# 6137  “Khayalan Tingkat Tinggi” bercerita tentang seseorang yang jatuh cinta pada pandangan pertama, t...
# 6139  #sule #njan #ratu #inibukantalkshow \nJangan lupa subscribe, like, share & comment S-PRO!\n\nLan...
# 6142  Official Music Video MANGKU PUREL"SHEPIN MISA"\nSongwriter by  NURBAYAN\nArangger by: DR.STUDIO\...
# 6142  Official Music Video MANGKU PUREL"SHEPIN MISA"\nSongwriter by  NURBAYAN\nArangger by: DR.STUDIO\...
#
# [3082 rows x 4 columns]

# %%
data.drop(columns="description", inplace=True)

# %%
data["all_text"] = data["title_emoji"] + " " + data["desc_emoji"]

# %%
X_train, X_dev, y_train, y_dev = train_test_split(
    data ["all_text"], data["category_id"], 
    test_size=.2,
    stratify=data ["category_id"],
    random_state=11
)
training_size = X_train.shape[0]
dev_size = X_dev.shape[0]
print(f"{training_size = }.. {dev_size = }")

vectorizer = TfidfVectorizer(
    min_df=.015,
    max_df=.7,
    ngram_range=(1, 1),
)
train_tfidf = vectorizer.fit_transform(X_train)
dev_tfidf = vectorizer.transform(X_dev)
print("Got train tf-idf with shape:", train_tfidf.shape)
print("Got dev tf-idf with shape:", dev_tfidf.shape)

train_tfidf = pd.DataFrame(train_tfidf.toarray(), columns=vectorizer.get_feature_names_out())
dev_tfidf = pd.DataFrame(dev_train.toarray(), columns=vectorizer.get_feature_names_out())
# Out:
# training_size = 4925.. dev_size = 1232
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-100-d1b7b3a14324> in <module>
#      14     ngram_range=(1, 1),
#      15 )
# ---> 16 train_tfidf = vectorizer.fit_transform(X_train)
#      17 dev_tfidf = vectorizer.transform(X_dev)
#      18 print("Got train tf-idf with shape:", train_tfidf.shape)
#
# ~\anaconda3\lib\site-packages\sklearn\feature_extraction\text.py in fit_transform(self, raw_documents, y)
#    1838         """
#    1839         self._check_params()
# -> 1840         X = super().fit_transform(raw_documents)
#    1841         self._tfidf.fit(X)
#    1842         # X is already a transformed view of raw_documents so
#
# ~\anaconda3\lib\site-packages\sklearn\feature_extraction\text.py in fit_transform(self, raw_documents, y)
#    1196         max_features = self.max_features
#    1197
# -> 1198         vocabulary, X = self._count_vocab(raw_documents,
#    1199                                           self.fixed_vocabulary_)
#    1200
#
# ~\anaconda3\lib\site-packages\sklearn\feature_extraction\text.py in _count_vocab(self, raw_documents, fixed_vocab)
#    1108         for doc in raw_documents:
#    1109             feature_counter = {}
# -> 1110             for feature in analyze(doc):
#    1111                 try:
#    1112                     feature_idx = vocabulary[feature]
#
# ~\anaconda3\lib\site-packages\sklearn\feature_extraction\text.py in _analyze(doc, analyzer, tokenizer, ngrams, preprocessor, decoder, stop_words)
#      97
#      98     if decoder is not None:
# ---> 99         doc = decoder(doc)
#     100     if analyzer is not None:
#     101         doc = analyzer(doc)
#
# ~\anaconda3\lib\site-packages\sklearn\feature_extraction\text.py in decode(self, doc)
#     217
#     218         if doc is np.nan:
# --> 219             raise ValueError("np.nan is an invalid document, expected byte or "
#     220                              "unicode string.")
#     221
#
# ValueError: np.nan is an invalid document, expected byte or unicode string.

# %% [markdown]
# ## Model Training & Evaluation

# %%
dict_models = {
"logistic_regression": LogisticRegression(),
"naive_bayes": MultinomialNB(),
"svm": LinearSVC(random_state=11),
"decision_tree": DecisionTreeClassifier(random_state=11),
"random_forest": RandomForestClassifier(random_state=11)
}

# %%
for model in dict_models.values():
    print(f"-- {model.__class__.__name__} --") 
    model.fit(train_tfidf, y_train)
y_pred = model.predict(dev_tfidf)
print("Reports on dev set:", classification_report(y_dev, y_pred), sep="\n")
# Out:
# -- LogisticRegression --
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-102-ddd97a2ab5fd> in <module>
#       1 for model in dict_models.values():
#       2     print(f"-- {model.__class__.__name__} --")
# ----> 3     model.fit(train_tfidf, y_train)
#       4 y_pred = model.predict(dev_tfidf)
#       5 print("Reports on dev set:", classification_report(y_dev, y_pred), sep="\n")
#
# NameError: name 'train_tfidf' is not defined

# %% [markdown]
# ## LinearSVC

# %%
svm_grid_search = GridSearchCV(
dict_models["svm"],
{"C": (10, 1, .1, .05, .01)},
)
svm_grid_search.fit(train_tfidf, y_train)
svm_pred_dev = svm_grid_search.predict(dev_tfidf)
print("Reports on train set:",
classification_report(
y_train,
svm_grid_search.predict(train_tfidf)
), sep="\n")
print("Reports on dev set:", classification_report(y_dev, svm_pred_dev), sep="\n")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-39-9991ba84759e> in <module>
#       3 {"C": (10, 1, .1, .05, .01)},
#       4 )
# ----> 5 svm_grid_search.fit(train_tfidf, y_train)
#       6 svm_pred_dev = svm_grid_search.predict(dev_tfidf)
#       7 print("Reports on train set:",
#
# NameError: name 'train_tfidf' is not defined

# %%
svm_grid_search.best_params_

# %% [markdown]
# ## RandomForestClassifier

# %%
random_forest_grid_search = GridSearchCV(
dict_models["random_forest"],
{
"n_estimators": (10, 20, 25, 50, 75, 100, 125),
"max_depth": (5, 10, 25, 50),
}
)
random_forest_grid_search.fit(train_tfidf, y_train)
random_forest_pred = random_forest_grid_search.predict(dev_tfidf)
print("Reports on train set:",
classification_report(
y_train,
random_forest_grid_search.predict(train_tfidf)
),
sep="\n"
)
print("Reports on dev set:", classification_report(y_dev, random_forest_pred), sep="\n")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-0087d140bede> in <module>
#       6 }
#       7 )
# ----> 8 random_forest_grid_search.fit(train_tfidf, y_train)
#       9 random_forest_pred = random_forest_grid_search.predict(dev_tfidf)
#      10 print("Reports on train set:",
#
# NameError: name 'train_tfidf' is not defined

# %%
random_forest_grid_search.best_params_

# %% [markdown]
# ## Save Model

# %%
model = Pipeline([
("vectorizer", TfidfVectorizer(
min_df=.015,
max_df=.7,
ngram_range=(1, 1),
)),
("model", RandomForestClassifier(
max_depth=50,
n_estimators=75,
random_state=11
))
])
# training
model.fit(X_train, y_train)
pred = model.predict(X_dev)
print("Reports on train set:",
classification_report(
y_train,
model.predict(X_train)
),
sep="\n"
)
print("Reports on dev set:", classification_report(y_dev, pred), sep="\n")

# %%
joblib.dump(model, "/modelyt.joblib")

# %%
model = joblib.load("modelyt.joblib")
print(model.get_params())

# %%
preds = model.predict(X_dev)
print(classification_report(y_dev, preds))
